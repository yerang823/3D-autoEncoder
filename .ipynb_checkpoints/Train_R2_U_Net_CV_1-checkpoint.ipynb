# %%
from PIL import Image

import os 
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt


from keras.models import *
from keras.optimizers import *
from keras import backend as K
from keras.layers.core import Lambda
from keras.layers.merge import concatenate,add
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras.layers import Activation,Conv2DTranspose, Reshape
from keras.layers import Input, merge, Conv2D, MaxPooling2D, UpSampling2D, Dropout, Cropping2D, concatenate, multiply, core
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, History, ReduceLROnPlateau, EarlyStopping
from keras.utils.generic_utils import get_custom_objects
from keras.utils import multi_gpu_model
from keras.models import Model
from keras.regularizers import l2

from data import *
from metrics import iou_score
from metrics import jaccard_score
from metrics import f_score
from metrics import f1_score
from metrics import f2_score
from metrics import dice_score

from losses import jaccard_loss
from losses import bce_jaccard_loss
from losses import cce_jaccard_loss
from losses import dice_loss
from losses import bce_dice_loss
from losses import cce_dice_loss

os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# Using TensorFlow backend.

# %%
pwd
# Out:
# '/home/ubuntu/JJG/spine/code'

# %%
epsilon = K.epsilon()
gamma = 0
alpha = 0.6
beta = 0.6

  
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall


def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision


def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou


def balanced_loss(y_true, y_pred):
    pt = y_pred * y_true + (1-y_pred) * (1-y_true)
    pt = K.clip(pt, epsilon, 1-epsilon)
    CE = -K.log(pt)
    BL = alpha * CE
    
    return K.sum(BL, axis=1)


def focal_loss(y_true, y_pred):
    pt = y_pred * y_true + (1-y_pred) * (1-y_true)
    pt = K.clip(pt, epsilon, 1-epsilon)
    CE = -K.log(pt)
    FL = alpha * K.pow(1-pt, gamma) * CE
    
    return K.sum(FL, axis=1)


def dice_coef(y_true, y_pred, smooth=0.001):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)


def cus_loss(y_true, y_pred):
    
    return (1 - beta) * focal_loss(y_true, y_pred) + beta * dice_coef_loss(y_true, y_pred)


def tversky_loss(beta):
      def loss(y_true, y_pred):
        numerator = tf.reduce_sum(y_true * y_pred, axis=-1)
        denominator = y_true * y_pred + beta * (1 - y_true) * y_pred + (1 - beta) * y_true * (1 - y_pred)

        return 1 - (numerator + 1) / (tf.reduce_sum(denominator, axis=-1) + 1)

      return loss


get_custom_objects().update({
    
    'cus_loss': cus_loss,
    'iou_coef' : iou_coef,
    'f1score' : f1score,
    'precision' : precision,
    'recall' : recall,
    'balanced_loss' : balanced_loss,
    'focal_loss' : focal_loss,
    'dice_coef' : dice_coef,
    'dice_coef_loss' : dice_coef_loss,
    'cus_loss' : cus_loss,
    'tversky_loss' : tversky_loss,
        
})

img_size = 512

# %%
image_all = np.load('../data/npy/image_all_512.npy') / 255
label_all = np.load('../data/npy/label_all_512.npy') / 255

print('All data num')
print('-'*30)
print(image_all.shape)
print(label_all.shape)
print('-'*30)


image_hold_1 = image_all[0:49,:,:,:] 
image_hold_2 = image_all[49:98,:,:,:] 
image_hold_3 = image_all[98:147,:,:,:] 
image_hold_4 = image_all[147:196,:,:,:] 
image_hold_5 = image_all[196:,:,:,:] 

label_hold_1 = label_all[0:49,:,:,:] 
label_hold_2 = label_all[49:98,:,:,:] 
label_hold_3 = label_all[98:147,:,:,:] 
label_hold_4 = label_all[147:196,:,:,:] 
label_hold_5 = label_all[196:,:,:,:]


print(image_hold_1.shape,'Hold_1')
print(image_hold_2.shape,'Hold_2')
print(image_hold_3.shape,'Hold_3')
print(image_hold_4.shape,'Hold_4')
print(image_hold_5.shape,'Hold_5')

print('-'*30)

print(label_hold_1.shape,'Hold_1')
print(label_hold_2.shape,'Hold_2')
print(label_hold_3.shape,'Hold_3')
print(label_hold_4.shape,'Hold_4')
print(label_hold_5.shape,'Hold_5')
# Out:
# All data num
# ------------------------------
# (244, 512, 512, 1)
# (244, 512, 512, 1)
# ------------------------------
# (49, 512, 512, 1) Hold_1
# (49, 512, 512, 1) Hold_2
# (49, 512, 512, 1) Hold_3
# (49, 512, 512, 1) Hold_4
# (48, 512, 512, 1) Hold_5
# ------------------------------
# (49, 512, 512, 1) Hold_1
# (49, 512, 512, 1) Hold_2
# (49, 512, 512, 1) Hold_3
# (49, 512, 512, 1) Hold_4
# (48, 512, 512, 1) Hold_5

# %%
train_image_all = np.concatenate((image_hold_1,image_hold_3,image_hold_4,image_hold_5), axis=0)
train_label_all = np.concatenate((label_hold_1,label_hold_3,label_hold_4,label_hold_5), axis=0)


print('-'*30)
print('train data num')
print('-'*30)
print(train_image_all.shape)
print(train_label_all.shape)


image_fold_1 = train_image_all[0:40,:,:]
image_fold_2 = train_image_all[40:79,:,:]
image_fold_3 = train_image_all[79:118,:,:]
image_fold_4 = train_image_all[118:157,:,:]
image_fold_5 = train_image_all[157:,:,:]


label_fold_1 = train_label_all[0:40,:,:]
label_fold_2 = train_label_all[40:79,:,:]
label_fold_3 = train_label_all[79:118,:,:]
label_fold_4 = train_label_all[118:157,:,:]
label_fold_5 = train_label_all[157:,:,:]


print('-'*30)
print(image_fold_1.shape,'Fold_1')
print(image_fold_2.shape,'Fold_2')
print(image_fold_3.shape,'Fold_3')
print(image_fold_4.shape,'Fold_4')
print(image_fold_5.shape,'Fold_5')

print('-'*30)

print(label_fold_1.shape,'Fold_1')
print(label_fold_2.shape,'Fold_2')
print(label_fold_3.shape,'Fold_3')
print(label_fold_4.shape,'Fold_4')
print(label_fold_5.shape,'Fold_5')



train_image = np.concatenate((image_fold_1,image_fold_2,image_fold_3,image_fold_4), axis=0) 
train_label = np.concatenate((label_fold_1,label_fold_2,label_fold_3,label_fold_4), axis=0)


validation_image = image_fold_5
validation_label = label_fold_5


test_image = image_all[49:98,:,:,:]
test_label = label_all[49:98,:,:,:]


print('-'*30)
print('train data')
print('-'*30)
print(train_image.shape)
print(train_label.shape)

print('-'*30)
print('validation data')
print('-'*30)
print(validation_image.shape)
print(validation_label.shape)

print('-'*30)
print('test data')
print('-'*30)
print(test_image.shape)
print(test_label.shape)
# Out:
# ------------------------------
# train data num
# ------------------------------
# (195, 512, 512, 1)
# (195, 512, 512, 1)
# ------------------------------
# (40, 512, 512, 1) Fold_1
# (39, 512, 512, 1) Fold_2
# (39, 512, 512, 1) Fold_3
# (39, 512, 512, 1) Fold_4
# (38, 512, 512, 1) Fold_5
# ------------------------------
# (40, 512, 512, 1) Fold_1
# (39, 512, 512, 1) Fold_2
# (39, 512, 512, 1) Fold_3
# (39, 512, 512, 1) Fold_4
# (38, 512, 512, 1) Fold_5
# ------------------------------
# train data
# ------------------------------
# (157, 512, 512, 1)
# (157, 512, 512, 1)
# ------------------------------
# validation data
# ------------------------------
# (38, 512, 512, 1)
# (38, 512, 512, 1)
# ------------------------------
# test data
# ------------------------------
# (49, 512, 512, 1)
# (49, 512, 512, 1)

# %%
sam = 17
# train data
plt.figure(figsize=(20, 20))
plt.subplot(3,3,1)
plt.imshow(train_image[sam,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(3,3,2)
plt.imshow(train_label[sam,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(3,3,3)
plt.imshow(train_image[sam,:,:,0],cmap='gray',)
plt.imshow(train_label[sam,:,:,0],cmap='Reds',alpha=0.5)
plt.axis('off')

# validation data
plt.subplot(3,3,4)
plt.imshow(validation_image[sam,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(3,3,5)
plt.imshow(validation_label[sam,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(3,3,6)
plt.imshow(validation_image[sam,:,:,0],cmap='gray')
plt.imshow(validation_label[sam,:,:,0],cmap='Reds',alpha=0.5)
plt.axis('off')

# test data
plt.subplot(3,3,7)
plt.imshow(test_image[sam,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(3,3,8)
plt.imshow(test_label[sam,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(3,3,9)
plt.imshow(test_image[sam,:,:,0],cmap='gray')
plt.imshow(test_label[sam,:,:,0],cmap='Reds',alpha=0.5)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
def up_and_concate(down_layer, layer):
    
    in_channel = down_layer.get_shape().as_list()[3]

    # up = Conv2DTranspose(out_channel, [2, 2], strides=[2, 2])(down_layer)
    up = UpSampling2D(size=(2, 2))(down_layer)

    my_concat = Lambda(lambda x: K.concatenate([x[0], x[1]], axis=3))

    concate = my_concat([up, layer])

    return concate

def res_block(input_layer, out_n_filters, batch_normalization=False, kernel_size=[3, 3], stride=[1, 1],

              padding='same', data_format='channels_first'):
    if data_format == 'channels_first':
        input_n_filters = input_layer.get_shape().as_list()[1]
    else:
        input_n_filters = input_layer.get_shape().as_list()[3]

    layer = input_layer
    for i in range(2):
        layer = Conv2D(out_n_filters // 4, [1, 1], strides=stride, padding=padding, data_format=data_format)(layer)
        if batch_normalization:
            layer = BatchNormalization()(layer)
        layer = Activation('relu')(layer)
        layer = Conv2D(out_n_filters // 4, kernel_size, strides=stride, padding=padding, data_format=data_format)(layer)
        layer = Conv2D(out_n_filters, [1, 1], strides=stride, padding=padding, data_format=data_format)(layer)

    if out_n_filters != input_n_filters:
        skip_layer = Conv2D(out_n_filters, [1, 1], strides=stride, padding=padding, data_format=data_format)(
            input_layer)
    else:
        skip_layer = input_layer
    out_layer = add([layer, skip_layer])
    return out_layer


def rec_res_block(input_layer, out_n_filters, batch_normalization=False, kernel_size=[3, 3], stride=[1, 1],

                  padding='same'):
    input_n_filters = input_layer.get_shape().as_list()[3]

    if out_n_filters != input_n_filters:
        skip_layer = Conv2D(out_n_filters, [1, 1], strides=stride, padding=padding)(input_layer)
    else:
        skip_layer = input_layer

    layer = skip_layer
    
    for j in range(2):

        for i in range(2):
            if i == 0:

                layer1 = Conv2D(out_n_filters, kernel_size, strides=stride, padding=padding)(layer)
                layer1 = BatchNormalization()(layer1)
                layer1 = Activation('relu')(layer1)            
            
            layer1 = Conv2D(out_n_filters, kernel_size, strides=stride, padding=padding)(add([layer1, layer]))
            layer1 = BatchNormalization()(layer1)
            layer1 = Activation('relu')(layer1)
        layer = layer1

    out_layer = add([layer, skip_layer])
    return out_layer

# %%
#Recurrent Residual Convolutional Neural Network based on U-Net (R2U-Net)
def r2_unet(img_w, img_h, n_label):
    inputs = Input((img_w, img_h,1))
    x = inputs
    depth = 5
    features = 16
    skips = []
    for i in range(depth):
        x = rec_res_block(x, features)
        skips.append(x)
        x = MaxPooling2D((2, 2))(x)

        features = features * 2

    x = rec_res_block(x, features)

    for i in reversed(range(depth)):
        features = features // 2
        x = up_and_concate(x, skips[i])
        x = rec_res_block(x, features)

    conv6 = Conv2D(n_label, (1, 1), padding='same')(x)
    conv7 = core.Activation('sigmoid')(conv6)
    model = Model(inputs=inputs, outputs=conv7)
    #model.compile(optimizer=Adam(lr=1e-6), loss=[dice_coef_loss], metrics=['accuracy', dice_coef])
    return model

# %%
model = r2_unet(512, 512, 1)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 512, 512, 16) 32          input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 512, 512, 16) 2320        conv2d_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 512, 512, 16) 64          conv2d_158[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# session = tf.Session(config=config)

# model = multi_gpu_model(model,gpus=2)
model.compile(optimizer=Adam(lr=0.001), loss=dice_coef_loss, metrics=['accuracy', recall, precision, f1score, dice_coef])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=10, verbose=1, min_delta=1e-8)
earlystopper = EarlyStopping(monitor='val_loss', patience=20, verbose=1)
model_checkpoint = ModelCheckpoint('../result/model_save/model_spine_'+'_best_'+str(img_size)+'_CV_1'+'.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False)

callbacks_list = [reduce_lr, model_checkpoint, earlystopper]

# %%
print('-'*100)
print('Fitting model...')
print('-'*100)
hist = model.fit(train_image, train_label, validation_data=(validation_image, validation_label), batch_size=10, epochs=100, verbose=1, shuffle=True, callbacks=callbacks_list)
# Out:
# ----------------------------------------------------------------------------------------------------
# Fitting model...
# ----------------------------------------------------------------------------------------------------
# Train on 157 samples, validate on 38 samples
# Epoch 1/100
# 157/157 [==============================] - 31s 196ms/step - loss: 0.6950 - accuracy: 0.8215 - recall: 0.5992 - precision: 0.2491 - f1score: 0.3078 - dice_coef: 0.3077 - val_loss: 0.9104 - val_accuracy: 0.0435 - val_recall: 1.0000 - val_precision: 0.0470 - val_f1score: 0.0897 - val_dice_coef: 0.0897
#
# Epoch 00001: val_loss improved from inf to 0.91039, saving model to ../result/model_save/model_spine__best_512_CV_1.h5

# %%
print('-'*100)
print('predict test data')
print('-'*100)
test_imgs_pred = model.predict(test_image, batch_size=10, verbose=1)
np.save('../result/npy/test_pred_'+str(img_size)+'.npy', test_imgs_pred)

print('-'*100)
print('predict test data save done')
print('-'*100)

# %%
fig = plt.figure()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


fig = plt.figure()
plt.plot(hist.history['dice_coef'])
plt.plot(hist.history['val_dice_coef'])
plt.title('Dice Coefficient')
plt.ylabel('dice_coef')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

fig = plt.figure()
plt.plot(hist.history['recall'])
plt.plot(hist.history['val_recall'])
plt.title('Recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

fig = plt.figure()
plt.plot(hist.history['precision'])
plt.plot(hist.history['val_precision'])
plt.title('Precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def preds_Thresh(preds_test,Thresh_value):
    
    preds_mask = np.ndarray((len(test_image),img_size, img_size, 1), dtype=np.float32)
  
    preds_mask0 = preds_test[:,:,:,0] > Thresh_value
  
    preds_mask[:,:,:,0] = preds_mask0*1
    
    return preds_mask

# %%
preds_mask = preds_Thresh(test_imgs_pred,0.5)

toto = 0
plt.figure(figsize=(15, 15))
plt.subplot(2,3,1)
plt.imshow(test_image[toto,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(2,3,2)
plt.imshow(test_label[toto,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(2,3,3)
plt.imshow(test_image[toto,:,:,0],cmap='gray')
plt.imshow(test_label[toto,:,:,0],cmap='Reds' ,alpha=0.6)
plt.axis('off')
plt.subplot(2,3,4)
plt.imshow(test_image[toto,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(2,3,5)
plt.imshow(preds_mask[toto,:,:,0],cmap='gray')
plt.axis('off')
plt.subplot(2,3,6)
plt.imshow(test_image[toto,:,:,0],cmap='gray')
plt.imshow(preds_mask[toto,:,:,0],cmap='Reds' ,alpha=0.6)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
# print("array to image")
# preds_mask_1 = preds_mask
# imgs_name = np.load('../jin_data/npy/test_name_512.npy')
# for i in range(preds_mask_1.shape[0]):
#     img = preds_mask_1[i]
#     img = array_to_img(img)
#     img.save("../result/img/%s_pred.bmp"%imgs_name[i])

# %%
_loss, _acc, _precision, _recall, _f1score, _dice_coef = model.evaluate(test_image, test_label, batch_size=10, verbose=1)
print('loss: {:.3f}, accuracy: {:.3f}, precision: {:.3f}, recall: {:.3f}, f1score: {:.3f}, dice_coef:{:.3f}'.format(_loss, _acc*100, _precision*100, _recall*100, _f1score*100, _dice_coef*100))
# Out:
# 49/49 [==============================] - 1s 23ms/step
# loss: 1.000, accuracy: 94.851, precision: 0.000, recall: 0.000, f1score: 0.000, dice_coef:0.000
